# %% [markdown]
# ###  途中からニューロンの数が変わるモデル
# DropOutの理論を転用して、初めは使うニューロンの数を制限する。<br>
# 一定数エポックが経ったら、使っていなかったニューロンを開放してあげる。<br>
#
# 一番単純なモデル

# %%
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import torch.autograd as autograd
import torch.nn.functional as F
from torchvision import datasets, transforms, models
import matplotlib.pyplot as plt
import os
from sklearn.utils import shuffle
from sklearn.metrics import f1_score
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
config={
    'BatchSize':128,
    'seed':42,
    'n_epochs' : 100,
    'lr' : 0.001
}

# %%
trainval_dataset = datasets.CIFAR10('data/cifar10', train=True,download=True,transform=transforms.ToTensor())

# 前処理を定義
transform = transforms.Compose([transforms.ToTensor()])

trainval_dataset = datasets.CIFAR10('data/cifar10', train=True, transform=transform)

# trainとvalidに分割
train_dataset, val_dataset = torch.utils.data.random_split(trainval_dataset, [len(trainval_dataset)-10000, 10000],generator=torch.Generator().manual_seed(config['seed']))

dataloader_train = torch.utils.data.DataLoader(
    train_dataset,
    batch_size=config['BatchSize'],
    shuffle=True
)

dataloader_valid = torch.utils.data.DataLoader(
    val_dataset,
    batch_size=config['BatchSize'],
    shuffle=True
)

print("Train data number:{}, Valid data number: {}".format(len(train_dataset), len(val_dataset)))
# Out:
# Files already downloaded and verified
# Train data number:40000, Valid data number: 10000

# %%
class Bio_genesis(nn.Module):
    def __init__(self,ratio=0.5):
        super().__init__()
        self.ratio=ratio
        self.Mask=True
    
    def forward(self,x):
        if self.training:
            if epoch <30:
                self.mask=torch.rand(*x.size()) > self.ratio
                return x * self.mask.to(x.device)
                
            else:
                
                return  x * (1.0 - self.ratio)
        else:
            return x

# %%
class NeurogenesisModel(nn.Module):
    def __init__(self):
        super(NeurogenesisModel, self).__init__()
        self.conv1=nn.Conv2d(3, 32, 3)       # 32x32x3 -> 30x30x32
        self.bn1=nn.BatchNorm2d(32)
        self.av1=nn.ReLU()
        self.pool1=nn.AvgPool2d(2)                  # 30x30x32 -> 15x15x32
        self.conv2=nn.Conv2d(32, 64, 3)             # 15x15x32 -> 13x13x64
        self.bn2=nn.BatchNorm2d(64)
        self.av2=nn.ReLU()
        self.pool2=nn.AvgPool2d(2)                  # 13x13x64 -> 6x6x64
        self.conv3=nn.Conv2d(64, 128, 3)            # 6x6x64 -> 4x4x128
        self.bn3=nn.BatchNorm2d(128)
        self.av3=nn.ReLU()
        self.pool3=nn.AvgPool2d(2)                  # 4x4x128 -> 2x2x128
        self.flatten=nn.Flatten()
        self.fc1=nn.Linear(2*2*128, 256)
        self.relu=nn.ReLU()
        self.genesis=Bio_genesis()
        self.fc2=nn.Linear(256, 10)
        #self.fc1 = nn.Linear(input_size, hidden_size)
        #self.relu = nn.ReLU()
        #self.fc2 = nn.Linear(hidden_size, output_size)
        

    def forward(self, x):
        x=self.conv1(x)
        x=self.bn1(x)
        x=self.av1(x)
        x=self.pool1(x)
        x=self.conv2(x)
        x=self.bn2(x)
        x=self.av2(x)
        x=self.pool2(x)     
        x=self.conv3(x)
        x=self.bn3(x)
        x=self.av3(x)
        x=self.pool3(x)  
        x=self.flatten(x)
        x=self.fc1(x)
        x=self.relu(x)
        x=self.genesis(x)
        x=self.fc2(x)
        return x

model=NeurogenesisModel()

# %%
def init_weights(m):  # Heの初期化
    if type(m) == nn.Linear or type(m) == nn.Conv2d:
        torch.nn.init.kaiming_normal_(m.weight)
        m.bias.data.fill_(0.0)

model.apply(init_weights)

device='cuda'
model.to(device)
optimizer2 = optim.Adam(model.parameters(), lr=config['lr'])
loss_function = nn.CrossEntropyLoss()

# %%
accuracy_train=[]
cost_train=[]
accuracy_valid=[]
cost_valid=[]

for epoch in range(config['n_epochs']):
    losses_train = []
    losses_valid = []

    model.train()
    n_train = 0
    acc_train = 0
    for x, t in dataloader_train:
        n_train += t.size()[0]

        model.zero_grad()  # 勾配の初期化

        x = x.to(device)  # テンソルをGPUに移動
        t = t.to(device)

        y = model.forward(x)  # 順伝播


        loss = loss_function(y, t)  # 誤差(クロスエントロピー誤差関数)の計算

        loss.backward()  # 誤差の逆伝播

        optimizer2.step()  # パラメータの更新

        pred = y.argmax(1)  # 最大値を取るラベルを予測ラベルとする

        acc_train += (pred == t).float().sum().item()
        losses_train.append(loss.tolist())

    accuracy_train.append(acc_train/n_train)
    cost_train.append(np.mean(losses_train))

    model.eval()
    n_val = 0
    acc_val = 0
    for x, t in dataloader_valid:
        n_val += t.size()[0]

        x = x.to(device)  # テンソルをGPUに移動
        t = t.to(device)

        y = model.forward(x)  # 順伝播

        loss = loss_function(y, t)  # 誤差(クロスエントロピー誤差関数)の計算

        pred = y.argmax(1)  # 最大値を取るラベルを予測ラベルとする

        acc_val += (pred == t).float().sum().item()
        losses_valid.append(loss.tolist())
    accuracy_valid.append(acc_val/n_val)
    cost_valid.append(np.mean(losses_valid))

    print('EPOCH: {}, Train [Loss: {:.3f}, Accuracy: {:.3f}], Valid [Loss: {:.3f}, Accuracy: {:.3f}]]'.format(
        epoch+1,
        np.mean(losses_train),
        acc_train/n_train,
        np.mean(losses_valid),
        acc_val/n_val,
    ))


x=np.arange(1,config['n_epochs']+1,1)
y1=accuracy_train
y2=cost_train
y3 = accuracy_valid
y4 = cost_valid
c1,c2= 'blue', 'orange'
l1,l2,l3,l4 = 'accuracy_train', 'cost_train','accuracy_valid','cost_valid'
xl1, xl2= 'epochs', 'epochs'
yl1, yl2= 'accuracy', 'cost'
fig = plt.figure(figsize = (20,6))
ax1 = fig.add_subplot(1, 2, 1)
ax2 = fig.add_subplot(1, 2, 2)
ax1.plot(x, y1, color=c1, label=l1)
ax1.plot(x,y3,color=c2,label=l3)
ax2.plot(x, y2, color=c1, label=l2)
ax2.plot(x,y4,color=c2,label=l4)
ax1.set_xlabel(xl1)
ax2.set_xlabel(xl2)
ax1.set_ylabel(yl1)
ax2.set_ylabel(yl2)
ax1.legend(loc = 'upper right')
ax2.legend(loc = 'upper right')

plt.show()
# Out:
# EPOCH: 1, Train [Loss: 1.542, Accuracy: 0.440], Valid [Loss: 1.634, Accuracy: 0.515]]
# EPOCH: 2, Train [Loss: 1.172, Accuracy: 0.582], Valid [Loss: 1.293, Accuracy: 0.610]]
# EPOCH: 3, Train [Loss: 1.017, Accuracy: 0.644], Valid [Loss: 1.277, Accuracy: 0.630]]
# EPOCH: 4, Train [Loss: 0.922, Accuracy: 0.675], Valid [Loss: 1.066, Accuracy: 0.681]]
# EPOCH: 5, Train [Loss: 0.849, Accuracy: 0.702], Valid [Loss: 1.130, Accuracy: 0.685]]
# EPOCH: 6, Train [Loss: 0.783, Accuracy: 0.725], Valid [Loss: 1.116, Accuracy: 0.692]]
# EPOCH: 7, Train [Loss: 0.730, Accuracy: 0.746], Valid [Loss: 0.963, Accuracy: 0.734]]
# EPOCH: 8, Train [Loss: 0.686, Accuracy: 0.760], Valid [Loss: 1.026, Accuracy: 0.723]]
# EPOCH: 9, Train [Loss: 0.645, Accuracy: 0.772], Valid [Loss: 1.054, Accuracy: 0.733]]
# EPOCH: 10, Train [Loss: 0.604, Accuracy: 0.787], Valid [Loss: 0.984, Accuracy: 0.749]]
# EPOCH: 11, Train [Loss: 0.572, Accuracy: 0.801], Valid [Loss: 1.002, Accuracy: 0.740]]
# EPOCH: 12, Train [Loss: 0.544, Accuracy: 0.810], Valid [Loss: 0.973, Accuracy: 0.753]]
# EPOCH: 13, Train [Loss: 0.513, Accuracy: 0.819], Valid [Loss: 0.993, Accuracy: 0.753]]
# EPOCH: 14, Train [Loss: 0.482, Accuracy: 0.829], Valid [Loss: 1.207, Accuracy: 0.731]]
# EPOCH: 15, Train [Loss: 0.453, Accuracy: 0.841], Valid [Loss: 1.126, Accuracy: 0.745]]
# EPOCH: 16, Train [Loss: 0.434, Accuracy: 0.848], Valid [Loss: 0.983, Accuracy: 0.767]]
# EPOCH: 17, Train [Loss: 0.408, Accuracy: 0.857], Valid [Loss: 1.190, Accuracy: 0.740]]
# EPOCH: 18, Train [Loss: 0.383, Accuracy: 0.866], Valid [Loss: 1.175, Accuracy: 0.755]]
# EPOCH: 19, Train [Loss: 0.360, Accuracy: 0.873], Valid [Loss: 1.108, Accuracy: 0.771]]
# EPOCH: 20, Train [Loss: 0.346, Accuracy: 0.879], Valid [Loss: 1.161, Accuracy: 0.770]]
# EPOCH: 21, Train [Loss: 0.321, Accuracy: 0.887], Valid [Loss: 1.271, Accuracy: 0.758]]
# EPOCH: 22, Train [Loss: 0.306, Accuracy: 0.890], Valid [Loss: 1.263, Accuracy: 0.760]]
# EPOCH: 23, Train [Loss: 0.292, Accuracy: 0.896], Valid [Loss: 1.422, Accuracy: 0.752]]
# EPOCH: 24, Train [Loss: 0.273, Accuracy: 0.903], Valid [Loss: 1.280, Accuracy: 0.761]]
# EPOCH: 25, Train [Loss: 0.257, Accuracy: 0.908], Valid [Loss: 1.398, Accuracy: 0.756]]
# EPOCH: 26, Train [Loss: 0.243, Accuracy: 0.914], Valid [Loss: 1.397, Accuracy: 0.765]]
# EPOCH: 27, Train [Loss: 0.232, Accuracy: 0.917], Valid [Loss: 1.347, Accuracy: 0.769]]
# EPOCH: 28, Train [Loss: 0.219, Accuracy: 0.923], Valid [Loss: 1.427, Accuracy: 0.765]]
# EPOCH: 29, Train [Loss: 0.210, Accuracy: 0.925], Valid [Loss: 1.509, Accuracy: 0.764]]
# EPOCH: 30, Train [Loss: 0.197, Accuracy: 0.931], Valid [Loss: 1.508, Accuracy: 0.776]]
# EPOCH: 31, Train [Loss: 0.094, Accuracy: 0.969], Valid [Loss: 1.791, Accuracy: 0.761]]
# EPOCH: 32, Train [Loss: 0.083, Accuracy: 0.973], Valid [Loss: 1.810, Accuracy: 0.766]]
# EPOCH: 33, Train [Loss: 0.066, Accuracy: 0.979], Valid [Loss: 2.079, Accuracy: 0.754]]
# EPOCH: 34, Train [Loss: 0.070, Accuracy: 0.978], Valid [Loss: 1.994, Accuracy: 0.761]]
# EPOCH: 35, Train [Loss: 0.068, Accuracy: 0.978], Valid [Loss: 1.970, Accuracy: 0.761]]
# EPOCH: 36, Train [Loss: 0.065, Accuracy: 0.980], Valid [Loss: 1.987, Accuracy: 0.764]]
# EPOCH: 37, Train [Loss: 0.055, Accuracy: 0.983], Valid [Loss: 2.170, Accuracy: 0.758]]
# EPOCH: 38, Train [Loss: 0.053, Accuracy: 0.983], Valid [Loss: 2.358, Accuracy: 0.756]]
# EPOCH: 39, Train [Loss: 0.064, Accuracy: 0.979], Valid [Loss: 2.424, Accuracy: 0.760]]
# EPOCH: 40, Train [Loss: 0.060, Accuracy: 0.980], Valid [Loss: 2.231, Accuracy: 0.758]]
# EPOCH: 41, Train [Loss: 0.045, Accuracy: 0.985], Valid [Loss: 2.458, Accuracy: 0.757]]
# EPOCH: 42, Train [Loss: 0.036, Accuracy: 0.989], Valid [Loss: 2.457, Accuracy: 0.759]]
# EPOCH: 43, Train [Loss: 0.051, Accuracy: 0.983], Valid [Loss: 2.266, Accuracy: 0.769]]
# EPOCH: 44, Train [Loss: 0.042, Accuracy: 0.986], Valid [Loss: 2.345, Accuracy: 0.758]]
# EPOCH: 45, Train [Loss: 0.031, Accuracy: 0.991], Valid [Loss: 2.470, Accuracy: 0.771]]
# EPOCH: 46, Train [Loss: 0.048, Accuracy: 0.984], Valid [Loss: 2.424, Accuracy: 0.762]]
# EPOCH: 47, Train [Loss: 0.040, Accuracy: 0.987], Valid [Loss: 2.678, Accuracy: 0.740]]
# EPOCH: 48, Train [Loss: 0.039, Accuracy: 0.987], Valid [Loss: 2.464, Accuracy: 0.774]]
# EPOCH: 49, Train [Loss: 0.035, Accuracy: 0.989], Valid [Loss: 2.670, Accuracy: 0.763]]
# EPOCH: 50, Train [Loss: 0.038, Accuracy: 0.988], Valid [Loss: 2.627, Accuracy: 0.762]]
# EPOCH: 51, Train [Loss: 0.035, Accuracy: 0.989], Valid [Loss: 2.600, Accuracy: 0.759]]
# EPOCH: 52, Train [Loss: 0.028, Accuracy: 0.991], Valid [Loss: 4.434, Accuracy: 0.677]]
# EPOCH: 53, Train [Loss: 0.041, Accuracy: 0.986], Valid [Loss: 2.697, Accuracy: 0.755]]
# EPOCH: 54, Train [Loss: 0.035, Accuracy: 0.989], Valid [Loss: 2.506, Accuracy: 0.773]]
# EPOCH: 55, Train [Loss: 0.023, Accuracy: 0.993], Valid [Loss: 2.681, Accuracy: 0.760]]
# EPOCH: 56, Train [Loss: 0.026, Accuracy: 0.991], Valid [Loss: 2.834, Accuracy: 0.755]]
# EPOCH: 57, Train [Loss: 0.031, Accuracy: 0.990], Valid [Loss: 2.787, Accuracy: 0.766]]
# EPOCH: 58, Train [Loss: 0.035, Accuracy: 0.988], Valid [Loss: 2.712, Accuracy: 0.762]]
# EPOCH: 59, Train [Loss: 0.031, Accuracy: 0.990], Valid [Loss: 2.887, Accuracy: 0.758]]
# EPOCH: 60, Train [Loss: 0.027, Accuracy: 0.991], Valid [Loss: 2.781, Accuracy: 0.765]]
# EPOCH: 61, Train [Loss: 0.029, Accuracy: 0.991], Valid [Loss: 2.923, Accuracy: 0.754]]
# EPOCH: 62, Train [Loss: 0.026, Accuracy: 0.992], Valid [Loss: 2.708, Accuracy: 0.763]]
# EPOCH: 63, Train [Loss: 0.016, Accuracy: 0.995], Valid [Loss: 2.909, Accuracy: 0.761]]
# EPOCH: 64, Train [Loss: 0.031, Accuracy: 0.989], Valid [Loss: 3.143, Accuracy: 0.750]]
# EPOCH: 65, Train [Loss: 0.027, Accuracy: 0.991], Valid [Loss: 2.805, Accuracy: 0.761]]
# EPOCH: 66, Train [Loss: 0.023, Accuracy: 0.993], Valid [Loss: 3.170, Accuracy: 0.753]]
# EPOCH: 67, Train [Loss: 0.028, Accuracy: 0.991], Valid [Loss: 2.772, Accuracy: 0.770]]
# EPOCH: 68, Train [Loss: 0.019, Accuracy: 0.994], Valid [Loss: 3.050, Accuracy: 0.755]]
# EPOCH: 69, Train [Loss: 0.034, Accuracy: 0.989], Valid [Loss: 3.029, Accuracy: 0.753]]
# EPOCH: 70, Train [Loss: 0.026, Accuracy: 0.991], Valid [Loss: 2.858, Accuracy: 0.767]]
# EPOCH: 71, Train [Loss: 0.017, Accuracy: 0.995], Valid [Loss: 3.366, Accuracy: 0.751]]
# EPOCH: 72, Train [Loss: 0.025, Accuracy: 0.992], Valid [Loss: 3.313, Accuracy: 0.745]]
# EPOCH: 73, Train [Loss: 0.019, Accuracy: 0.993], Valid [Loss: 3.220, Accuracy: 0.759]]
# EPOCH: 74, Train [Loss: 0.023, Accuracy: 0.992], Valid [Loss: 3.165, Accuracy: 0.755]]
# EPOCH: 75, Train [Loss: 0.025, Accuracy: 0.992], Valid [Loss: 2.885, Accuracy: 0.770]]
# EPOCH: 76, Train [Loss: 0.024, Accuracy: 0.993], Valid [Loss: 3.056, Accuracy: 0.760]]
# EPOCH: 77, Train [Loss: 0.020, Accuracy: 0.994], Valid [Loss: 2.970, Accuracy: 0.771]]
# EPOCH: 78, Train [Loss: 0.011, Accuracy: 0.997], Valid [Loss: 3.148, Accuracy: 0.770]]
# EPOCH: 79, Train [Loss: 0.020, Accuracy: 0.993], Valid [Loss: 2.991, Accuracy: 0.764]]
# EPOCH: 80, Train [Loss: 0.021, Accuracy: 0.993], Valid [Loss: 3.013, Accuracy: 0.766]]
# EPOCH: 81, Train [Loss: 0.015, Accuracy: 0.995], Valid [Loss: 3.764, Accuracy: 0.747]]
# EPOCH: 82, Train [Loss: 0.027, Accuracy: 0.991], Valid [Loss: 4.208, Accuracy: 0.724]]
# EPOCH: 83, Train [Loss: 0.030, Accuracy: 0.990], Valid [Loss: 3.017, Accuracy: 0.771]]
# EPOCH: 84, Train [Loss: 0.018, Accuracy: 0.994], Valid [Loss: 3.046, Accuracy: 0.768]]
# EPOCH: 85, Train [Loss: 0.010, Accuracy: 0.997], Valid [Loss: 3.186, Accuracy: 0.764]]
# EPOCH: 86, Train [Loss: 0.016, Accuracy: 0.995], Valid [Loss: 3.057, Accuracy: 0.769]]
# EPOCH: 87, Train [Loss: 0.021, Accuracy: 0.993], Valid [Loss: 3.088, Accuracy: 0.770]]
# EPOCH: 88, Train [Loss: 0.016, Accuracy: 0.995], Valid [Loss: 2.875, Accuracy: 0.772]]
# EPOCH: 89, Train [Loss: 0.018, Accuracy: 0.994], Valid [Loss: 3.384, Accuracy: 0.753]]
# EPOCH: 90, Train [Loss: 0.025, Accuracy: 0.992], Valid [Loss: 3.112, Accuracy: 0.771]]
# EPOCH: 91, Train [Loss: 0.014, Accuracy: 0.995], Valid [Loss: 3.599, Accuracy: 0.759]]
# EPOCH: 92, Train [Loss: 0.015, Accuracy: 0.995], Valid [Loss: 3.467, Accuracy: 0.757]]
# EPOCH: 93, Train [Loss: 0.016, Accuracy: 0.995], Valid [Loss: 3.036, Accuracy: 0.768]]
# EPOCH: 94, Train [Loss: 0.021, Accuracy: 0.993], Valid [Loss: 3.230, Accuracy: 0.760]]
# EPOCH: 95, Train [Loss: 0.019, Accuracy: 0.994], Valid [Loss: 3.531, Accuracy: 0.752]]
# EPOCH: 96, Train [Loss: 0.015, Accuracy: 0.995], Valid [Loss: 3.545, Accuracy: 0.742]]
# EPOCH: 97, Train [Loss: 0.023, Accuracy: 0.992], Valid [Loss: 3.065, Accuracy: 0.760]]
# EPOCH: 98, Train [Loss: 0.014, Accuracy: 0.996], Valid [Loss: 3.242, Accuracy: 0.763]]
# EPOCH: 99, Train [Loss: 0.013, Accuracy: 0.996], Valid [Loss: 3.310, Accuracy: 0.764]]
# EPOCH: 100, Train [Loss: 0.012, Accuracy: 0.996], Valid [Loss: 3.325, Accuracy: 0.772]]

# %%
import numpy as np

def save_weights(model, filename):
    weights = {}

    # モデルの各層の名前とパラメータを取得
    for name, param in model.named_parameters():
        if 'weight' in name:
            weights[name] = param.detach().cpu().numpy()

    # .npz ファイルとして出力
    np.savez(filename, **weights)

save_weights(model, 'weights.npz')
data = np.load('weights.npz')

for key in data.keys():
    print(key, data[key].shape)
# Out:
# conv1.weight (32, 3, 3, 3)
# bn1.weight (32,)
# conv2.weight (64, 32, 3, 3)
# bn2.weight (64,)
# conv3.weight (128, 64, 3, 3)
# bn3.weight (128,)
# fc1.weight (256, 512)
# fc2.weight (10, 256)

# %%
conv_net2 = nn.Sequential(
    nn.Conv2d(3, 32, 3),              # 32x32x3 -> 30x30x32
    nn.BatchNorm2d(32),
    nn.ReLU(),
    nn.AvgPool2d(2),                  # 30x30x32 -> 15x15x32
    nn.Conv2d(32, 64, 3),             # 15x15x32 -> 13x13x64
    nn.BatchNorm2d(64),
    nn.ReLU(),
    nn.AvgPool2d(2),                  # 13x13x64 -> 6x6x64
    nn.Conv2d(64, 128, 3),            # 6x6x64 -> 4x4x128
    nn.BatchNorm2d(128),
    nn.ReLU(),
    nn.AvgPool2d(2),                  # 4x4x128 -> 2x2x128
    nn.Flatten(),
    nn.Linear(2*2*128, 256),
    nn.ReLU(),
    nn.Linear(256, 10)
)


def init_weights(m):  # Heの初期化
    if type(m) == nn.Linear or type(m) == nn.Conv2d:
        torch.nn.init.kaiming_normal_(m.weight)
        m.bias.data.fill_(0.0)


conv_net2.apply(init_weights)

batch_size = 100
n_epochs = 5
lr = 0.01
device = 'cuda'

conv_net2.to(device)
optimizer2 = optim.Adam(conv_net2.parameters(), lr=lr)
loss_function = nn.CrossEntropyLoss()  # nn.ClossEntropyLossは，出力のsoftmax変換と，正解ラベルのone-hot vector化の機能を持っている

# %%
accuracy_train=[]
cost_train=[]
accuracy_valid=[]
cost_valid=[]

for epoch in range(config['n_epochs']):
    losses_train = []
    losses_valid = []

    conv_net2.train()
    n_train = 0
    acc_train = 0
    for x, t in dataloader_train:
        n_train += t.size()[0]

        conv_net2.zero_grad()  # 勾配の初期化

        x = x.to(device)  # テンソルをGPUに移動
        t = t.to(device)

        y = conv_net2.forward(x)  # 順伝播


        loss = loss_function(y, t)  # 誤差(クロスエントロピー誤差関数)の計算

        loss.backward()  # 誤差の逆伝播

        optimizer2.step()  # パラメータの更新

        pred = y.argmax(1)  # 最大値を取るラベルを予測ラベルとする

        acc_train += (pred == t).float().sum().item()
        losses_train.append(loss.tolist())

    accuracy_train.append(acc_train/n_train)
    cost_train.append(np.mean(losses_train))

    conv_net2.eval()
    n_val = 0
    acc_val = 0
    for x, t in dataloader_valid:
        n_val += t.size()[0]

        x = x.to(device)  # テンソルをGPUに移動
        t = t.to(device)

        y = conv_net2.forward(x)  # 順伝播

        loss = loss_function(y, t)  # 誤差(クロスエントロピー誤差関数)の計算

        pred = y.argmax(1)  # 最大値を取るラベルを予測ラベルとする

        acc_val += (pred == t).float().sum().item()
        losses_valid.append(loss.tolist())
    accuracy_valid.append(acc_val/n_val)
    cost_valid.append(np.mean(losses_valid))

    print('EPOCH: {}, Train [Loss: {:.3f}, Accuracy: {:.3f}], Valid [Loss: {:.3f}, Accuracy: {:.3f}]]'.format(
        epoch+1,
        np.mean(losses_train),
        acc_train/n_train,
        np.mean(losses_valid),
        acc_val/n_val,
    ))


x=np.arange(1,config['n_epochs']+1,1)
y1=accuracy_train
y2=cost_train
y3 = accuracy_valid
y4 = cost_valid
c1,c2= 'blue', 'orange'
l1,l2,l3,l4 = 'accuracy_train', 'cost_train','accuracy_valid','cost_valid'
xl1, xl2= 'epochs', 'epochs'
yl1, yl2= 'accuracy', 'cost'
fig = plt.figure(figsize = (20,6))
ax1 = fig.add_subplot(1, 2, 1)
ax2 = fig.add_subplot(1, 2, 2)
ax1.plot(x, y1, color=c1, label=l1)
ax1.plot(x,y3,color=c2,label=l3)
ax2.plot(x, y2, color=c1, label=l2)
ax2.plot(x,y4,color=c2,label=l4)
ax1.set_xlabel(xl1)
ax2.set_xlabel(xl2)
ax1.set_ylabel(yl1)
ax2.set_ylabel(yl2)
ax1.legend(loc = 'upper right')
ax2.legend(loc = 'upper right')

plt.show()
# Out:
# EPOCH: 1, Train [Loss: 1.444, Accuracy: 0.485], Valid [Loss: 1.219, Accuracy: 0.570]]
# EPOCH: 2, Train [Loss: 0.999, Accuracy: 0.646], Valid [Loss: 2.075, Accuracy: 0.447]]
# EPOCH: 3, Train [Loss: 0.849, Accuracy: 0.701], Valid [Loss: 0.991, Accuracy: 0.667]]
# EPOCH: 4, Train [Loss: 0.731, Accuracy: 0.744], Valid [Loss: 1.274, Accuracy: 0.584]]
# EPOCH: 5, Train [Loss: 0.651, Accuracy: 0.774], Valid [Loss: 0.927, Accuracy: 0.679]]
# EPOCH: 6, Train [Loss: 0.583, Accuracy: 0.795], Valid [Loss: 0.960, Accuracy: 0.681]]
# EPOCH: 7, Train [Loss: 0.525, Accuracy: 0.814], Valid [Loss: 1.420, Accuracy: 0.575]]
# EPOCH: 8, Train [Loss: 0.475, Accuracy: 0.834], Valid [Loss: 0.967, Accuracy: 0.708]]
# EPOCH: 9, Train [Loss: 0.430, Accuracy: 0.848], Valid [Loss: 0.872, Accuracy: 0.724]]
# EPOCH: 10, Train [Loss: 0.384, Accuracy: 0.865], Valid [Loss: 1.041, Accuracy: 0.698]]
# EPOCH: 11, Train [Loss: 0.354, Accuracy: 0.876], Valid [Loss: 1.036, Accuracy: 0.705]]
# EPOCH: 12, Train [Loss: 0.316, Accuracy: 0.890], Valid [Loss: 1.294, Accuracy: 0.670]]
# EPOCH: 13, Train [Loss: 0.285, Accuracy: 0.900], Valid [Loss: 1.597, Accuracy: 0.606]]
# EPOCH: 14, Train [Loss: 0.262, Accuracy: 0.908], Valid [Loss: 1.767, Accuracy: 0.624]]
# EPOCH: 15, Train [Loss: 0.240, Accuracy: 0.916], Valid [Loss: 1.195, Accuracy: 0.714]]
# EPOCH: 16, Train [Loss: 0.218, Accuracy: 0.921], Valid [Loss: 1.125, Accuracy: 0.733]]
# EPOCH: 17, Train [Loss: 0.196, Accuracy: 0.932], Valid [Loss: 1.115, Accuracy: 0.742]]
# EPOCH: 18, Train [Loss: 0.193, Accuracy: 0.930], Valid [Loss: 1.240, Accuracy: 0.719]]
# EPOCH: 19, Train [Loss: 0.183, Accuracy: 0.935], Valid [Loss: 1.529, Accuracy: 0.686]]
# EPOCH: 20, Train [Loss: 0.161, Accuracy: 0.942], Valid [Loss: 1.164, Accuracy: 0.745]]
# EPOCH: 21, Train [Loss: 0.163, Accuracy: 0.943], Valid [Loss: 1.270, Accuracy: 0.732]]
# EPOCH: 22, Train [Loss: 0.154, Accuracy: 0.946], Valid [Loss: 1.728, Accuracy: 0.684]]
# EPOCH: 23, Train [Loss: 0.137, Accuracy: 0.952], Valid [Loss: 1.408, Accuracy: 0.734]]
# EPOCH: 24, Train [Loss: 0.130, Accuracy: 0.955], Valid [Loss: 1.871, Accuracy: 0.679]]
# EPOCH: 25, Train [Loss: 0.140, Accuracy: 0.951], Valid [Loss: 1.629, Accuracy: 0.699]]
# EPOCH: 26, Train [Loss: 0.129, Accuracy: 0.955], Valid [Loss: 1.514, Accuracy: 0.716]]
# EPOCH: 27, Train [Loss: 0.107, Accuracy: 0.963], Valid [Loss: 1.868, Accuracy: 0.690]]
# EPOCH: 28, Train [Loss: 0.120, Accuracy: 0.959], Valid [Loss: 1.419, Accuracy: 0.744]]
# EPOCH: 29, Train [Loss: 0.101, Accuracy: 0.965], Valid [Loss: 1.429, Accuracy: 0.737]]
# EPOCH: 30, Train [Loss: 0.101, Accuracy: 0.965], Valid [Loss: 1.628, Accuracy: 0.726]]
# EPOCH: 31, Train [Loss: 0.117, Accuracy: 0.960], Valid [Loss: 3.130, Accuracy: 0.585]]
# EPOCH: 32, Train [Loss: 0.101, Accuracy: 0.964], Valid [Loss: 2.225, Accuracy: 0.642]]
# EPOCH: 33, Train [Loss: 0.100, Accuracy: 0.966], Valid [Loss: 1.644, Accuracy: 0.732]]
# EPOCH: 34, Train [Loss: 0.106, Accuracy: 0.964], Valid [Loss: 1.929, Accuracy: 0.694]]
# EPOCH: 35, Train [Loss: 0.082, Accuracy: 0.972], Valid [Loss: 1.719, Accuracy: 0.731]]
# EPOCH: 36, Train [Loss: 0.085, Accuracy: 0.972], Valid [Loss: 1.701, Accuracy: 0.733]]
# EPOCH: 37, Train [Loss: 0.109, Accuracy: 0.963], Valid [Loss: 1.542, Accuracy: 0.736]]
# EPOCH: 38, Train [Loss: 0.078, Accuracy: 0.973], Valid [Loss: 1.998, Accuracy: 0.717]]
# EPOCH: 39, Train [Loss: 0.079, Accuracy: 0.973], Valid [Loss: 2.186, Accuracy: 0.704]]
# EPOCH: 40, Train [Loss: 0.090, Accuracy: 0.970], Valid [Loss: 2.101, Accuracy: 0.694]]
# EPOCH: 41, Train [Loss: 0.079, Accuracy: 0.973], Valid [Loss: 1.807, Accuracy: 0.723]]
# EPOCH: 42, Train [Loss: 0.083, Accuracy: 0.972], Valid [Loss: 1.667, Accuracy: 0.746]]
# EPOCH: 43, Train [Loss: 0.072, Accuracy: 0.975], Valid [Loss: 2.108, Accuracy: 0.712]]
# EPOCH: 44, Train [Loss: 0.086, Accuracy: 0.972], Valid [Loss: 1.764, Accuracy: 0.737]]
# EPOCH: 45, Train [Loss: 0.085, Accuracy: 0.972], Valid [Loss: 1.935, Accuracy: 0.731]]
# EPOCH: 46, Train [Loss: 0.068, Accuracy: 0.978], Valid [Loss: 1.896, Accuracy: 0.729]]
# EPOCH: 47, Train [Loss: 0.082, Accuracy: 0.973], Valid [Loss: 1.797, Accuracy: 0.735]]
# EPOCH: 48, Train [Loss: 0.067, Accuracy: 0.978], Valid [Loss: 1.931, Accuracy: 0.726]]
# EPOCH: 49, Train [Loss: 0.073, Accuracy: 0.976], Valid [Loss: 1.724, Accuracy: 0.743]]
# EPOCH: 50, Train [Loss: 0.083, Accuracy: 0.973], Valid [Loss: 1.683, Accuracy: 0.740]]
# EPOCH: 51, Train [Loss: 0.067, Accuracy: 0.977], Valid [Loss: 1.821, Accuracy: 0.745]]
# EPOCH: 52, Train [Loss: 0.075, Accuracy: 0.975], Valid [Loss: 1.730, Accuracy: 0.748]]
# EPOCH: 53, Train [Loss: 0.057, Accuracy: 0.981], Valid [Loss: 1.860, Accuracy: 0.739]]
# EPOCH: 54, Train [Loss: 0.068, Accuracy: 0.978], Valid [Loss: 1.952, Accuracy: 0.736]]
# EPOCH: 55, Train [Loss: 0.090, Accuracy: 0.971], Valid [Loss: 1.737, Accuracy: 0.743]]
# EPOCH: 56, Train [Loss: 0.054, Accuracy: 0.982], Valid [Loss: 2.241, Accuracy: 0.719]]
# EPOCH: 57, Train [Loss: 0.061, Accuracy: 0.980], Valid [Loss: 2.012, Accuracy: 0.735]]
# EPOCH: 58, Train [Loss: 0.061, Accuracy: 0.980], Valid [Loss: 2.143, Accuracy: 0.713]]
# EPOCH: 59, Train [Loss: 0.071, Accuracy: 0.977], Valid [Loss: 1.923, Accuracy: 0.744]]
# EPOCH: 60, Train [Loss: 0.061, Accuracy: 0.980], Valid [Loss: 1.873, Accuracy: 0.751]]
# EPOCH: 61, Train [Loss: 0.058, Accuracy: 0.981], Valid [Loss: 2.198, Accuracy: 0.724]]
# EPOCH: 62, Train [Loss: 0.061, Accuracy: 0.980], Valid [Loss: 2.166, Accuracy: 0.735]]
# EPOCH: 63, Train [Loss: 0.060, Accuracy: 0.981], Valid [Loss: 2.324, Accuracy: 0.712]]
# EPOCH: 64, Train [Loss: 0.061, Accuracy: 0.981], Valid [Loss: 1.929, Accuracy: 0.747]]
# EPOCH: 65, Train [Loss: 0.050, Accuracy: 0.983], Valid [Loss: 1.995, Accuracy: 0.748]]
# EPOCH: 66, Train [Loss: 0.066, Accuracy: 0.979], Valid [Loss: 1.940, Accuracy: 0.747]]
# EPOCH: 67, Train [Loss: 0.062, Accuracy: 0.980], Valid [Loss: 2.114, Accuracy: 0.742]]
# EPOCH: 68, Train [Loss: 0.066, Accuracy: 0.979], Valid [Loss: 2.069, Accuracy: 0.735]]
# EPOCH: 69, Train [Loss: 0.062, Accuracy: 0.981], Valid [Loss: 1.919, Accuracy: 0.754]]
# EPOCH: 70, Train [Loss: 0.054, Accuracy: 0.982], Valid [Loss: 2.142, Accuracy: 0.734]]
# EPOCH: 71, Train [Loss: 0.053, Accuracy: 0.983], Valid [Loss: 2.323, Accuracy: 0.726]]
# EPOCH: 72, Train [Loss: 0.049, Accuracy: 0.984], Valid [Loss: 2.101, Accuracy: 0.746]]
# EPOCH: 73, Train [Loss: 0.062, Accuracy: 0.981], Valid [Loss: 2.026, Accuracy: 0.748]]
# EPOCH: 74, Train [Loss: 0.049, Accuracy: 0.984], Valid [Loss: 2.065, Accuracy: 0.748]]
# EPOCH: 75, Train [Loss: 0.057, Accuracy: 0.983], Valid [Loss: 2.228, Accuracy: 0.727]]
# EPOCH: 76, Train [Loss: 0.060, Accuracy: 0.981], Valid [Loss: 2.000, Accuracy: 0.743]]
# EPOCH: 77, Train [Loss: 0.053, Accuracy: 0.984], Valid [Loss: 2.298, Accuracy: 0.737]]
# EPOCH: 78, Train [Loss: 0.062, Accuracy: 0.981], Valid [Loss: 1.988, Accuracy: 0.751]]
# EPOCH: 79, Train [Loss: 0.044, Accuracy: 0.986], Valid [Loss: 2.258, Accuracy: 0.747]]
# EPOCH: 80, Train [Loss: 0.050, Accuracy: 0.985], Valid [Loss: 2.386, Accuracy: 0.712]]
# EPOCH: 81, Train [Loss: 0.051, Accuracy: 0.984], Valid [Loss: 2.223, Accuracy: 0.749]]
# EPOCH: 82, Train [Loss: 0.057, Accuracy: 0.981], Valid [Loss: 2.111, Accuracy: 0.751]]
# EPOCH: 83, Train [Loss: 0.056, Accuracy: 0.982], Valid [Loss: 2.314, Accuracy: 0.745]]
# EPOCH: 84, Train [Loss: 0.048, Accuracy: 0.984], Valid [Loss: 2.224, Accuracy: 0.740]]
# EPOCH: 85, Train [Loss: 0.040, Accuracy: 0.988], Valid [Loss: 2.205, Accuracy: 0.743]]
# EPOCH: 86, Train [Loss: 0.064, Accuracy: 0.980], Valid [Loss: 2.129, Accuracy: 0.748]]
# EPOCH: 87, Train [Loss: 0.047, Accuracy: 0.985], Valid [Loss: 2.334, Accuracy: 0.734]]
# EPOCH: 88, Train [Loss: 0.045, Accuracy: 0.985], Valid [Loss: 2.282, Accuracy: 0.752]]
# EPOCH: 89, Train [Loss: 0.064, Accuracy: 0.981], Valid [Loss: 2.058, Accuracy: 0.746]]
# EPOCH: 90, Train [Loss: 0.050, Accuracy: 0.984], Valid [Loss: 2.418, Accuracy: 0.735]]
# EPOCH: 91, Train [Loss: 0.042, Accuracy: 0.987], Valid [Loss: 2.196, Accuracy: 0.746]]
# EPOCH: 92, Train [Loss: 0.052, Accuracy: 0.985], Valid [Loss: 2.438, Accuracy: 0.736]]
# EPOCH: 93, Train [Loss: 0.043, Accuracy: 0.986], Valid [Loss: 2.707, Accuracy: 0.707]]
# EPOCH: 94, Train [Loss: 0.049, Accuracy: 0.984], Valid [Loss: 2.425, Accuracy: 0.741]]
# EPOCH: 95, Train [Loss: 0.038, Accuracy: 0.988], Valid [Loss: 2.399, Accuracy: 0.747]]
# EPOCH: 96, Train [Loss: 0.040, Accuracy: 0.987], Valid [Loss: 2.460, Accuracy: 0.733]]
# EPOCH: 97, Train [Loss: 0.057, Accuracy: 0.983], Valid [Loss: 2.701, Accuracy: 0.719]]
# EPOCH: 98, Train [Loss: 0.044, Accuracy: 0.986], Valid [Loss: 2.300, Accuracy: 0.747]]
# EPOCH: 99, Train [Loss: 0.042, Accuracy: 0.987], Valid [Loss: 2.318, Accuracy: 0.748]]
# EPOCH: 100, Train [Loss: 0.048, Accuracy: 0.985], Valid [Loss: 2.432, Accuracy: 0.734]]

# %%
import torchvision
testset = torchvision.datasets.CIFAR10(root='data', train=False, download=True, transform=transforms.ToTensor() )
testloader = torch.utils.data.DataLoader(testset, batch_size=4, shuffle=True, num_workers=2)

correct = 0
total = 0
# 勾配を記憶せず（学習せずに）に計算を行う
with torch.no_grad():
    for data in testloader:
        images, labels = data[0].to(device),data[1].to(device)
        outputs = model(images)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()
print('Accuracy of the network on the 10000 test images: %d %%' % (100 * correct / total))
# Out:
# Files already downloaded and verified
# Accuracy of the network on the 10000 test images: 76 %

# %%
import torchvision
testset = torchvision.datasets.CIFAR10(root='data', train=False, download=True, transform=transforms.ToTensor() )
testloader = torch.utils.data.DataLoader(testset, batch_size=4, shuffle=True, num_workers=2)

correct = 0
total = 0
# 勾配を記憶せず（学習せずに）に計算を行う
with torch.no_grad():
    for data in testloader:
        images, labels = data[0].to(device), data[1].to(device)
        outputs = conv_net2(images)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()
print('Accuracy of the network on the 10000 test images: %d %%' % (100 * correct / total))
# Out:
# Files already downloaded and verified
# Accuracy of the network on the 10000 test images: 72 %
