# %% [markdown]
# ###  途中からニューロンの数が変わるモデル
# DropOutの理論を転用して、初めは使うニューロンの数を制限する。<br>
# 一定数エポックが経ったら、使っていなかったニューロンを開放してあげる。<br>
#
# 一番単純なモデル

# %%
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import torch.autograd as autograd
import torch.nn.functional as F
from torchvision import datasets, transforms, models
import matplotlib.pyplot as plt
import os
from sklearn.utils import shuffle
from sklearn.metrics import f1_score
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
config={
    'BatchSize':128,
    'seed':42,
    'n_epochs' : 100,
    'lr' : 0.0001
}

# %%
trainval_dataset = datasets.CIFAR10('../data/cifar10', train=True,download=True,transform=transforms.ToTensor())

# 前処理を定義
transform = transforms.Compose([transforms.ToTensor()])

trainval_dataset = datasets.CIFAR10('../data/cifar10', train=True, transform=transform)

# trainとvalidに分割
train_dataset, val_dataset = torch.utils.data.random_split(trainval_dataset, [len(trainval_dataset)-10000, 10000],generator=torch.Generator().manual_seed(config['seed']))

dataloader_train = torch.utils.data.DataLoader(
    train_dataset,
    batch_size=config['BatchSize'],
    shuffle=True
)

dataloader_valid = torch.utils.data.DataLoader(
    val_dataset,
    batch_size=config['BatchSize'],
    shuffle=True
)

print("Train data number:{}, Valid data number: {}".format(len(train_dataset), len(val_dataset)))
# Out:
# Files already downloaded and verified
# Train data number:40000, Valid data number: 10000

# %%
class Bio_genesis(nn.Module):
    def __init__(self,ratio=0.5):
        super().__init__()
        self.ratio=ratio
        self.Mask=True
    
    def forward(self,x):
        if self.training:
            if epoch <30:
                self.mask=torch.rand(*x.size()) > self.ratio
                return x * self.mask.to(x.device)
                
            else:
                
                return  x * (1.0 - self.ratio)
        else:
            return x

# %%
class NeurogenesisModel(nn.Module):
    def __init__(self):
        super(NeurogenesisModel, self).__init__()
        self.conv1=nn.Conv2d(3, 32, 3)       # 32x32x3 -> 30x30x32
        self.bn1=nn.BatchNorm2d(32)
        self.av1=nn.ReLU()
        self.pool1=nn.AvgPool2d(2)                  # 30x30x32 -> 15x15x32
        self.conv2=nn.Conv2d(32, 64, 3)             # 15x15x32 -> 13x13x64
        self.bn2=nn.BatchNorm2d(64)
        self.av2=nn.ReLU()
        self.pool2=nn.AvgPool2d(2)                  # 13x13x64 -> 6x6x64
        self.conv3=nn.Conv2d(64, 128, 3)            # 6x6x64 -> 4x4x128
        self.bn3=nn.BatchNorm2d(128)
        self.av3=nn.ReLU()
        self.pool3=nn.AvgPool2d(2)                  # 4x4x128 -> 2x2x128
        self.flatten=nn.Flatten()
        self.fc1=nn.Linear(2*2*128, 256)
        self.relu=nn.ReLU()
        self.genesis=Bio_genesis()
        self.fc2=nn.Linear(256, 10)
        #self.fc1 = nn.Linear(input_size, hidden_size)
        #self.relu = nn.ReLU()
        #self.fc2 = nn.Linear(hidden_size, output_size)
        

    def forward(self, x):
        x=self.conv1(x)
        x=self.bn1(x)
        x=self.av1(x)
        x=self.pool1(x)
        x=self.conv2(x)
        x=self.bn2(x)
        x=self.av2(x)
        x=self.pool2(x)     
        x=self.conv3(x)
        x=self.bn3(x)
        x=self.av3(x)
        x=self.pool3(x)  
        x=self.flatten(x)
        x=self.fc1(x)
        x=self.relu(x)
        x=self.genesis(x)
        x=self.fc2(x)
        return x

model=NeurogenesisModel()

# %%
def init_weights(m):  # Heの初期化
    if type(m) == nn.Linear or type(m) == nn.Conv2d:
        torch.nn.init.kaiming_normal_(m.weight)
        m.bias.data.fill_(0.0)

model.apply(init_weights)

device='cuda'
model.to(device)
optimizer2 = optim.Adam(model.parameters(), lr=config['lr'])
loss_function = nn.CrossEntropyLoss()

# %%
accuracy_train=[]
cost_train=[]
accuracy_valid=[]
cost_valid=[]

for epoch in range(config['n_epochs']):
    losses_train = []
    losses_valid = []

    model.train()
    n_train = 0
    acc_train = 0
    for x, t in dataloader_train:
        n_train += t.size()[0]

        model.zero_grad()  # 勾配の初期化

        x = x.to(device)  # テンソルをGPUに移動
        t = t.to(device)

        y = model.forward(x)  # 順伝播


        loss = loss_function(y, t)  # 誤差(クロスエントロピー誤差関数)の計算

        loss.backward()  # 誤差の逆伝播

        optimizer2.step()  # パラメータの更新

        pred = y.argmax(1)  # 最大値を取るラベルを予測ラベルとする

        acc_train += (pred == t).float().sum().item()
        losses_train.append(loss.tolist())

    accuracy_train.append(acc_train/n_train)
    cost_train.append(np.mean(losses_train))

    model.eval()
    n_val = 0
    acc_val = 0
    for x, t in dataloader_valid:
        n_val += t.size()[0]

        x = x.to(device)  # テンソルをGPUに移動
        t = t.to(device)

        y = model.forward(x)  # 順伝播

        loss = loss_function(y, t)  # 誤差(クロスエントロピー誤差関数)の計算

        pred = y.argmax(1)  # 最大値を取るラベルを予測ラベルとする

        acc_val += (pred == t).float().sum().item()
        losses_valid.append(loss.tolist())
    accuracy_valid.append(acc_val/n_val)
    cost_valid.append(np.mean(losses_valid))

    print('EPOCH: {}, Train [Loss: {:.3f}, Accuracy: {:.3f}], Valid [Loss: {:.3f}, Accuracy: {:.3f}]]'.format(
        epoch+1,
        np.mean(losses_train),
        acc_train/n_train,
        np.mean(losses_valid),
        acc_val/n_val,
    ))


x=np.arange(1,config['n_epochs']+1,1)
y1=accuracy_train
y2=cost_train
y3 = accuracy_valid
y4 = cost_valid
c1,c2= 'blue', 'orange'
l1,l2,l3,l4 = 'accuracy_train', 'cost_train','accuracy_valid','cost_valid'
xl1, xl2= 'epochs', 'epochs'
yl1, yl2= 'accuracy', 'cost'
fig = plt.figure(figsize = (20,6))
ax1 = fig.add_subplot(1, 2, 1)
ax2 = fig.add_subplot(1, 2, 2)
ax1.plot(x, y1, color=c1, label=l1)
ax1.plot(x,y3,color=c2,label=l3)
ax2.plot(x, y2, color=c1, label=l2)
ax2.plot(x,y4,color=c2,label=l4)
ax1.set_xlabel(xl1)
ax2.set_xlabel(xl2)
ax1.set_ylabel(yl1)
ax2.set_ylabel(yl2)
ax1.legend(loc = 'upper right')
ax2.legend(loc = 'upper right')

plt.show()
# Out:
# EPOCH: 1, Train [Loss: 1.928, Accuracy: 0.298], Valid [Loss: 1.601, Accuracy: 0.437]]
# EPOCH: 2, Train [Loss: 1.593, Accuracy: 0.420], Valid [Loss: 1.439, Accuracy: 0.507]]
# EPOCH: 3, Train [Loss: 1.442, Accuracy: 0.481], Valid [Loss: 1.361, Accuracy: 0.543]]
# EPOCH: 4, Train [Loss: 1.336, Accuracy: 0.523], Valid [Loss: 1.303, Accuracy: 0.575]]
# EPOCH: 5, Train [Loss: 1.256, Accuracy: 0.555], Valid [Loss: 1.242, Accuracy: 0.592]]
# EPOCH: 6, Train [Loss: 1.195, Accuracy: 0.576], Valid [Loss: 1.213, Accuracy: 0.610]]
# EPOCH: 7, Train [Loss: 1.146, Accuracy: 0.596], Valid [Loss: 1.192, Accuracy: 0.624]]
# EPOCH: 8, Train [Loss: 1.102, Accuracy: 0.610], Valid [Loss: 1.162, Accuracy: 0.641]]
# EPOCH: 9, Train [Loss: 1.065, Accuracy: 0.626], Valid [Loss: 1.147, Accuracy: 0.649]]
# EPOCH: 10, Train [Loss: 1.036, Accuracy: 0.636], Valid [Loss: 1.116, Accuracy: 0.659]]
# EPOCH: 11, Train [Loss: 1.006, Accuracy: 0.648], Valid [Loss: 1.100, Accuracy: 0.665]]
# EPOCH: 12, Train [Loss: 0.980, Accuracy: 0.657], Valid [Loss: 1.113, Accuracy: 0.668]]
# EPOCH: 13, Train [Loss: 0.953, Accuracy: 0.666], Valid [Loss: 1.082, Accuracy: 0.678]]
# EPOCH: 14, Train [Loss: 0.931, Accuracy: 0.675], Valid [Loss: 1.064, Accuracy: 0.680]]
# EPOCH: 15, Train [Loss: 0.907, Accuracy: 0.682], Valid [Loss: 1.063, Accuracy: 0.689]]
# EPOCH: 16, Train [Loss: 0.892, Accuracy: 0.688], Valid [Loss: 1.049, Accuracy: 0.695]]
# EPOCH: 17, Train [Loss: 0.876, Accuracy: 0.695], Valid [Loss: 1.056, Accuracy: 0.692]]
# EPOCH: 18, Train [Loss: 0.855, Accuracy: 0.703], Valid [Loss: 1.061, Accuracy: 0.697]]
# EPOCH: 19, Train [Loss: 0.839, Accuracy: 0.708], Valid [Loss: 1.032, Accuracy: 0.699]]
# EPOCH: 20, Train [Loss: 0.821, Accuracy: 0.713], Valid [Loss: 1.040, Accuracy: 0.703]]
# EPOCH: 21, Train [Loss: 0.808, Accuracy: 0.718], Valid [Loss: 1.031, Accuracy: 0.711]]
# EPOCH: 22, Train [Loss: 0.789, Accuracy: 0.728], Valid [Loss: 1.009, Accuracy: 0.712]]
# EPOCH: 23, Train [Loss: 0.778, Accuracy: 0.731], Valid [Loss: 1.022, Accuracy: 0.710]]
# EPOCH: 24, Train [Loss: 0.770, Accuracy: 0.734], Valid [Loss: 1.006, Accuracy: 0.713]]
# EPOCH: 25, Train [Loss: 0.752, Accuracy: 0.738], Valid [Loss: 1.016, Accuracy: 0.717]]
# EPOCH: 26, Train [Loss: 0.738, Accuracy: 0.743], Valid [Loss: 1.071, Accuracy: 0.711]]
# EPOCH: 27, Train [Loss: 0.730, Accuracy: 0.745], Valid [Loss: 1.012, Accuracy: 0.715]]
# EPOCH: 28, Train [Loss: 0.719, Accuracy: 0.752], Valid [Loss: 0.996, Accuracy: 0.723]]
# EPOCH: 29, Train [Loss: 0.706, Accuracy: 0.754], Valid [Loss: 1.001, Accuracy: 0.724]]
# EPOCH: 30, Train [Loss: 0.696, Accuracy: 0.760], Valid [Loss: 0.990, Accuracy: 0.725]]
# EPOCH: 31, Train [Loss: 0.608, Accuracy: 0.792], Valid [Loss: 1.045, Accuracy: 0.726]]
# EPOCH: 32, Train [Loss: 0.594, Accuracy: 0.795], Valid [Loss: 1.053, Accuracy: 0.725]]
# EPOCH: 33, Train [Loss: 0.579, Accuracy: 0.803], Valid [Loss: 1.014, Accuracy: 0.732]]
# EPOCH: 34, Train [Loss: 0.565, Accuracy: 0.807], Valid [Loss: 1.031, Accuracy: 0.736]]
# EPOCH: 35, Train [Loss: 0.554, Accuracy: 0.811], Valid [Loss: 1.039, Accuracy: 0.733]]
# EPOCH: 36, Train [Loss: 0.541, Accuracy: 0.815], Valid [Loss: 1.041, Accuracy: 0.737]]
# EPOCH: 37, Train [Loss: 0.530, Accuracy: 0.819], Valid [Loss: 1.110, Accuracy: 0.723]]
# EPOCH: 38, Train [Loss: 0.517, Accuracy: 0.823], Valid [Loss: 1.061, Accuracy: 0.732]]
# EPOCH: 39, Train [Loss: 0.506, Accuracy: 0.828], Valid [Loss: 1.048, Accuracy: 0.734]]
# EPOCH: 40, Train [Loss: 0.495, Accuracy: 0.831], Valid [Loss: 1.085, Accuracy: 0.730]]
# EPOCH: 41, Train [Loss: 0.484, Accuracy: 0.839], Valid [Loss: 1.041, Accuracy: 0.740]]
# EPOCH: 42, Train [Loss: 0.470, Accuracy: 0.842], Valid [Loss: 1.037, Accuracy: 0.741]]
# EPOCH: 43, Train [Loss: 0.461, Accuracy: 0.845], Valid [Loss: 1.056, Accuracy: 0.736]]
# EPOCH: 44, Train [Loss: 0.450, Accuracy: 0.849], Valid [Loss: 1.065, Accuracy: 0.743]]
# EPOCH: 45, Train [Loss: 0.440, Accuracy: 0.855], Valid [Loss: 1.078, Accuracy: 0.741]]
# EPOCH: 46, Train [Loss: 0.430, Accuracy: 0.857], Valid [Loss: 1.071, Accuracy: 0.744]]
# EPOCH: 47, Train [Loss: 0.419, Accuracy: 0.861], Valid [Loss: 1.102, Accuracy: 0.743]]
# EPOCH: 48, Train [Loss: 0.408, Accuracy: 0.866], Valid [Loss: 1.079, Accuracy: 0.746]]
# EPOCH: 49, Train [Loss: 0.399, Accuracy: 0.869], Valid [Loss: 1.080, Accuracy: 0.742]]
# EPOCH: 50, Train [Loss: 0.390, Accuracy: 0.873], Valid [Loss: 1.084, Accuracy: 0.745]]
# EPOCH: 51, Train [Loss: 0.380, Accuracy: 0.876], Valid [Loss: 1.130, Accuracy: 0.740]]
# EPOCH: 52, Train [Loss: 0.372, Accuracy: 0.878], Valid [Loss: 1.150, Accuracy: 0.741]]
# EPOCH: 53, Train [Loss: 0.363, Accuracy: 0.883], Valid [Loss: 1.146, Accuracy: 0.747]]
# EPOCH: 54, Train [Loss: 0.354, Accuracy: 0.886], Valid [Loss: 1.149, Accuracy: 0.744]]
# EPOCH: 55, Train [Loss: 0.343, Accuracy: 0.890], Valid [Loss: 1.139, Accuracy: 0.746]]
# EPOCH: 56, Train [Loss: 0.338, Accuracy: 0.893], Valid [Loss: 1.127, Accuracy: 0.752]]
# EPOCH: 57, Train [Loss: 0.327, Accuracy: 0.896], Valid [Loss: 1.175, Accuracy: 0.744]]
# EPOCH: 58, Train [Loss: 0.318, Accuracy: 0.900], Valid [Loss: 1.163, Accuracy: 0.750]]
# EPOCH: 59, Train [Loss: 0.311, Accuracy: 0.903], Valid [Loss: 1.228, Accuracy: 0.744]]
# EPOCH: 60, Train [Loss: 0.305, Accuracy: 0.905], Valid [Loss: 1.191, Accuracy: 0.752]]
# EPOCH: 61, Train [Loss: 0.293, Accuracy: 0.909], Valid [Loss: 1.207, Accuracy: 0.747]]
# EPOCH: 62, Train [Loss: 0.287, Accuracy: 0.912], Valid [Loss: 1.198, Accuracy: 0.743]]
# EPOCH: 63, Train [Loss: 0.279, Accuracy: 0.915], Valid [Loss: 1.233, Accuracy: 0.745]]
# EPOCH: 64, Train [Loss: 0.272, Accuracy: 0.918], Valid [Loss: 1.245, Accuracy: 0.748]]
# EPOCH: 65, Train [Loss: 0.265, Accuracy: 0.920], Valid [Loss: 1.244, Accuracy: 0.746]]
# EPOCH: 66, Train [Loss: 0.257, Accuracy: 0.922], Valid [Loss: 1.255, Accuracy: 0.745]]
# EPOCH: 67, Train [Loss: 0.250, Accuracy: 0.925], Valid [Loss: 1.260, Accuracy: 0.746]]
# EPOCH: 68, Train [Loss: 0.243, Accuracy: 0.930], Valid [Loss: 1.295, Accuracy: 0.743]]
# EPOCH: 69, Train [Loss: 0.235, Accuracy: 0.931], Valid [Loss: 1.297, Accuracy: 0.742]]
# EPOCH: 70, Train [Loss: 0.230, Accuracy: 0.933], Valid [Loss: 1.309, Accuracy: 0.746]]
# EPOCH: 71, Train [Loss: 0.220, Accuracy: 0.936], Valid [Loss: 1.340, Accuracy: 0.746]]
# EPOCH: 72, Train [Loss: 0.215, Accuracy: 0.938], Valid [Loss: 1.329, Accuracy: 0.742]]
# EPOCH: 73, Train [Loss: 0.207, Accuracy: 0.942], Valid [Loss: 1.349, Accuracy: 0.743]]
# EPOCH: 74, Train [Loss: 0.201, Accuracy: 0.943], Valid [Loss: 1.430, Accuracy: 0.740]]
# EPOCH: 75, Train [Loss: 0.196, Accuracy: 0.945], Valid [Loss: 1.409, Accuracy: 0.742]]
# EPOCH: 76, Train [Loss: 0.189, Accuracy: 0.949], Valid [Loss: 1.407, Accuracy: 0.745]]
# EPOCH: 77, Train [Loss: 0.185, Accuracy: 0.950], Valid [Loss: 1.459, Accuracy: 0.737]]
# EPOCH: 78, Train [Loss: 0.180, Accuracy: 0.949], Valid [Loss: 1.434, Accuracy: 0.747]]
# EPOCH: 79, Train [Loss: 0.172, Accuracy: 0.955], Valid [Loss: 1.416, Accuracy: 0.746]]
# EPOCH: 80, Train [Loss: 0.167, Accuracy: 0.957], Valid [Loss: 1.440, Accuracy: 0.743]]
# EPOCH: 81, Train [Loss: 0.160, Accuracy: 0.959], Valid [Loss: 1.461, Accuracy: 0.744]]
# EPOCH: 82, Train [Loss: 0.154, Accuracy: 0.961], Valid [Loss: 1.510, Accuracy: 0.744]]
# EPOCH: 83, Train [Loss: 0.149, Accuracy: 0.963], Valid [Loss: 1.507, Accuracy: 0.741]]
# EPOCH: 84, Train [Loss: 0.144, Accuracy: 0.965], Valid [Loss: 1.499, Accuracy: 0.746]]
# EPOCH: 85, Train [Loss: 0.139, Accuracy: 0.967], Valid [Loss: 1.563, Accuracy: 0.740]]
# EPOCH: 86, Train [Loss: 0.135, Accuracy: 0.968], Valid [Loss: 1.572, Accuracy: 0.737]]
# EPOCH: 87, Train [Loss: 0.129, Accuracy: 0.970], Valid [Loss: 1.602, Accuracy: 0.742]]
# EPOCH: 88, Train [Loss: 0.126, Accuracy: 0.970], Valid [Loss: 1.643, Accuracy: 0.739]]
# EPOCH: 89, Train [Loss: 0.121, Accuracy: 0.972], Valid [Loss: 1.612, Accuracy: 0.738]]
# EPOCH: 90, Train [Loss: 0.118, Accuracy: 0.974], Valid [Loss: 1.641, Accuracy: 0.739]]
# EPOCH: 91, Train [Loss: 0.114, Accuracy: 0.974], Valid [Loss: 1.643, Accuracy: 0.743]]
# EPOCH: 92, Train [Loss: 0.110, Accuracy: 0.977], Valid [Loss: 1.646, Accuracy: 0.741]]
# EPOCH: 93, Train [Loss: 0.104, Accuracy: 0.979], Valid [Loss: 1.687, Accuracy: 0.742]]
# EPOCH: 94, Train [Loss: 0.102, Accuracy: 0.978], Valid [Loss: 1.690, Accuracy: 0.740]]
# EPOCH: 95, Train [Loss: 0.096, Accuracy: 0.980], Valid [Loss: 1.699, Accuracy: 0.740]]
# EPOCH: 96, Train [Loss: 0.092, Accuracy: 0.983], Valid [Loss: 1.740, Accuracy: 0.741]]
# EPOCH: 97, Train [Loss: 0.090, Accuracy: 0.983], Valid [Loss: 1.742, Accuracy: 0.738]]
# EPOCH: 98, Train [Loss: 0.087, Accuracy: 0.983], Valid [Loss: 1.812, Accuracy: 0.741]]
# EPOCH: 99, Train [Loss: 0.083, Accuracy: 0.985], Valid [Loss: 1.802, Accuracy: 0.737]]
# EPOCH: 100, Train [Loss: 0.080, Accuracy: 0.986], Valid [Loss: 1.826, Accuracy: 0.741]]

# %%
import numpy as np

def save_weights(model, filename):
    weights = {}

    # モデルの各層の名前とパラメータを取得
    for name, param in model.named_parameters():
        if 'weight' in name:
            weights[name] = param.detach().cpu().numpy()

    # .npz ファイルとして出力
    np.savez(filename, **weights)

save_weights(model, 'weights.npz')
data = np.load('weights.npz')

for key in data.keys():
    print(key, data[key].shape)
# Out:
# conv1.weight (32, 3, 3, 3)
# bn1.weight (32,)
# conv2.weight (64, 32, 3, 3)
# bn2.weight (64,)
# conv3.weight (128, 64, 3, 3)
# bn3.weight (128,)
# fc1.weight (256, 512)
# fc2.weight (10, 256)

# %%
conv_net2 = nn.Sequential(
    nn.Conv2d(3, 32, 3),              # 32x32x3 -> 30x30x32
    nn.BatchNorm2d(32),
    nn.ReLU(),
    nn.AvgPool2d(2),                  # 30x30x32 -> 15x15x32
    nn.Conv2d(32, 64, 3),             # 15x15x32 -> 13x13x64
    nn.BatchNorm2d(64),
    nn.ReLU(),
    nn.AvgPool2d(2),                  # 13x13x64 -> 6x6x64
    nn.Conv2d(64, 128, 3),            # 6x6x64 -> 4x4x128
    nn.BatchNorm2d(128),
    nn.ReLU(),
    nn.AvgPool2d(2),                  # 4x4x128 -> 2x2x128
    nn.Flatten(),
    nn.Linear(2*2*128, 256),
    nn.ReLU(),
    nn.Linear(256, 10)
)


def init_weights(m):  # Heの初期化
    if type(m) == nn.Linear or type(m) == nn.Conv2d:
        torch.nn.init.kaiming_normal_(m.weight)
        m.bias.data.fill_(0.0)


conv_net2.apply(init_weights)

batch_size = 100
n_epochs = 5
lr = 0.01
device = 'cuda'

conv_net2.to(device)
optimizer2 = optim.Adam(conv_net2.parameters(), lr=lr)
loss_function = nn.CrossEntropyLoss()  # nn.ClossEntropyLossは，出力のsoftmax変換と，正解ラベルのone-hot vector化の機能を持っている

# %%
accuracy_train=[]
cost_train=[]
accuracy_valid=[]
cost_valid=[]

for epoch in range(config['n_epochs']):
    losses_train = []
    losses_valid = []

    conv_net2.train()
    n_train = 0
    acc_train = 0
    for x, t in dataloader_train:
        n_train += t.size()[0]

        conv_net2.zero_grad()  # 勾配の初期化

        x = x.to(device)  # テンソルをGPUに移動
        t = t.to(device)

        y = conv_net2.forward(x)  # 順伝播


        loss = loss_function(y, t)  # 誤差(クロスエントロピー誤差関数)の計算

        loss.backward()  # 誤差の逆伝播

        optimizer2.step()  # パラメータの更新

        pred = y.argmax(1)  # 最大値を取るラベルを予測ラベルとする

        acc_train += (pred == t).float().sum().item()
        losses_train.append(loss.tolist())

    accuracy_train.append(acc_train/n_train)
    cost_train.append(np.mean(losses_train))

    conv_net2.eval()
    n_val = 0
    acc_val = 0
    for x, t in dataloader_valid:
        n_val += t.size()[0]

        x = x.to(device)  # テンソルをGPUに移動
        t = t.to(device)

        y = conv_net2.forward(x)  # 順伝播

        loss = loss_function(y, t)  # 誤差(クロスエントロピー誤差関数)の計算

        pred = y.argmax(1)  # 最大値を取るラベルを予測ラベルとする

        acc_val += (pred == t).float().sum().item()
        losses_valid.append(loss.tolist())
    accuracy_valid.append(acc_val/n_val)
    cost_valid.append(np.mean(losses_valid))

    print('EPOCH: {}, Train [Loss: {:.3f}, Accuracy: {:.3f}], Valid [Loss: {:.3f}, Accuracy: {:.3f}]]'.format(
        epoch+1,
        np.mean(losses_train),
        acc_train/n_train,
        np.mean(losses_valid),
        acc_val/n_val,
    ))


x=np.arange(1,config['n_epochs']+1,1)
y1=accuracy_train
y2=cost_train
y3 = accuracy_valid
y4 = cost_valid
c1,c2= 'blue', 'orange'
l1,l2,l3,l4 = 'accuracy_train', 'cost_train','accuracy_valid','cost_valid'
xl1, xl2= 'epochs', 'epochs'
yl1, yl2= 'accuracy', 'cost'
fig = plt.figure(figsize = (20,6))
ax1 = fig.add_subplot(1, 2, 1)
ax2 = fig.add_subplot(1, 2, 2)
ax1.plot(x, y1, color=c1, label=l1)
ax1.plot(x,y3,color=c2,label=l3)
ax2.plot(x, y2, color=c1, label=l2)
ax2.plot(x,y4,color=c2,label=l4)
ax1.set_xlabel(xl1)
ax2.set_xlabel(xl2)
ax1.set_ylabel(yl1)
ax2.set_ylabel(yl2)
ax1.legend(loc = 'upper right')
ax2.legend(loc = 'upper right')

plt.show()
# Out:
# EPOCH: 1, Train [Loss: 1.497, Accuracy: 0.462], Valid [Loss: 1.325, Accuracy: 0.528]]
# EPOCH: 2, Train [Loss: 1.038, Accuracy: 0.632], Valid [Loss: 1.235, Accuracy: 0.587]]
# EPOCH: 3, Train [Loss: 0.860, Accuracy: 0.696], Valid [Loss: 0.963, Accuracy: 0.663]]
# EPOCH: 4, Train [Loss: 0.737, Accuracy: 0.744], Valid [Loss: 1.014, Accuracy: 0.650]]
# EPOCH: 5, Train [Loss: 0.650, Accuracy: 0.773], Valid [Loss: 0.827, Accuracy: 0.717]]
# EPOCH: 6, Train [Loss: 0.586, Accuracy: 0.795], Valid [Loss: 0.946, Accuracy: 0.681]]
# EPOCH: 7, Train [Loss: 0.528, Accuracy: 0.817], Valid [Loss: 1.541, Accuracy: 0.586]]
# EPOCH: 8, Train [Loss: 0.477, Accuracy: 0.835], Valid [Loss: 0.843, Accuracy: 0.724]]
# EPOCH: 9, Train [Loss: 0.425, Accuracy: 0.850], Valid [Loss: 1.065, Accuracy: 0.673]]
# EPOCH: 10, Train [Loss: 0.393, Accuracy: 0.863], Valid [Loss: 1.505, Accuracy: 0.612]]
# EPOCH: 11, Train [Loss: 0.351, Accuracy: 0.877], Valid [Loss: 1.007, Accuracy: 0.710]]
# EPOCH: 12, Train [Loss: 0.316, Accuracy: 0.890], Valid [Loss: 0.914, Accuracy: 0.730]]
# EPOCH: 13, Train [Loss: 0.281, Accuracy: 0.901], Valid [Loss: 1.342, Accuracy: 0.686]]
# EPOCH: 14, Train [Loss: 0.273, Accuracy: 0.903], Valid [Loss: 1.145, Accuracy: 0.712]]
# EPOCH: 15, Train [Loss: 0.235, Accuracy: 0.918], Valid [Loss: 1.149, Accuracy: 0.713]]
# EPOCH: 16, Train [Loss: 0.224, Accuracy: 0.921], Valid [Loss: 1.124, Accuracy: 0.733]]
# EPOCH: 17, Train [Loss: 0.211, Accuracy: 0.925], Valid [Loss: 1.057, Accuracy: 0.734]]
# EPOCH: 18, Train [Loss: 0.183, Accuracy: 0.935], Valid [Loss: 1.143, Accuracy: 0.742]]
# EPOCH: 19, Train [Loss: 0.188, Accuracy: 0.934], Valid [Loss: 1.432, Accuracy: 0.703]]
# EPOCH: 20, Train [Loss: 0.180, Accuracy: 0.936], Valid [Loss: 1.378, Accuracy: 0.722]]
# EPOCH: 21, Train [Loss: 0.156, Accuracy: 0.945], Valid [Loss: 1.365, Accuracy: 0.715]]
# EPOCH: 22, Train [Loss: 0.147, Accuracy: 0.949], Valid [Loss: 1.200, Accuracy: 0.750]]
# EPOCH: 23, Train [Loss: 0.138, Accuracy: 0.951], Valid [Loss: 1.413, Accuracy: 0.742]]
# EPOCH: 24, Train [Loss: 0.132, Accuracy: 0.955], Valid [Loss: 1.312, Accuracy: 0.743]]
# EPOCH: 25, Train [Loss: 0.133, Accuracy: 0.952], Valid [Loss: 1.364, Accuracy: 0.745]]
# EPOCH: 26, Train [Loss: 0.126, Accuracy: 0.957], Valid [Loss: 1.783, Accuracy: 0.706]]
# EPOCH: 27, Train [Loss: 0.127, Accuracy: 0.957], Valid [Loss: 1.382, Accuracy: 0.745]]
# EPOCH: 28, Train [Loss: 0.124, Accuracy: 0.958], Valid [Loss: 1.533, Accuracy: 0.736]]
# EPOCH: 29, Train [Loss: 0.109, Accuracy: 0.962], Valid [Loss: 1.487, Accuracy: 0.746]]
# EPOCH: 30, Train [Loss: 0.099, Accuracy: 0.965], Valid [Loss: 1.633, Accuracy: 0.734]]
# EPOCH: 31, Train [Loss: 0.107, Accuracy: 0.964], Valid [Loss: 1.627, Accuracy: 0.729]]
# EPOCH: 32, Train [Loss: 0.100, Accuracy: 0.965], Valid [Loss: 1.695, Accuracy: 0.728]]
# EPOCH: 33, Train [Loss: 0.102, Accuracy: 0.965], Valid [Loss: 1.732, Accuracy: 0.724]]
# EPOCH: 34, Train [Loss: 0.107, Accuracy: 0.964], Valid [Loss: 1.606, Accuracy: 0.740]]
# EPOCH: 35, Train [Loss: 0.097, Accuracy: 0.967], Valid [Loss: 1.644, Accuracy: 0.735]]
# EPOCH: 36, Train [Loss: 0.089, Accuracy: 0.970], Valid [Loss: 1.520, Accuracy: 0.756]]
# EPOCH: 37, Train [Loss: 0.078, Accuracy: 0.973], Valid [Loss: 1.614, Accuracy: 0.739]]
# EPOCH: 38, Train [Loss: 0.096, Accuracy: 0.968], Valid [Loss: 1.483, Accuracy: 0.747]]
# EPOCH: 39, Train [Loss: 0.092, Accuracy: 0.969], Valid [Loss: 1.653, Accuracy: 0.744]]
# EPOCH: 40, Train [Loss: 0.074, Accuracy: 0.975], Valid [Loss: 1.892, Accuracy: 0.720]]
# EPOCH: 41, Train [Loss: 0.086, Accuracy: 0.971], Valid [Loss: 1.929, Accuracy: 0.715]]
# EPOCH: 42, Train [Loss: 0.100, Accuracy: 0.966], Valid [Loss: 1.697, Accuracy: 0.740]]
# EPOCH: 43, Train [Loss: 0.065, Accuracy: 0.978], Valid [Loss: 1.763, Accuracy: 0.741]]
# EPOCH: 44, Train [Loss: 0.065, Accuracy: 0.977], Valid [Loss: 1.778, Accuracy: 0.749]]
# EPOCH: 45, Train [Loss: 0.084, Accuracy: 0.972], Valid [Loss: 1.847, Accuracy: 0.745]]
# EPOCH: 46, Train [Loss: 0.078, Accuracy: 0.975], Valid [Loss: 1.898, Accuracy: 0.717]]
# EPOCH: 47, Train [Loss: 0.077, Accuracy: 0.974], Valid [Loss: 1.752, Accuracy: 0.737]]
# EPOCH: 48, Train [Loss: 0.072, Accuracy: 0.975], Valid [Loss: 1.747, Accuracy: 0.749]]
# EPOCH: 49, Train [Loss: 0.068, Accuracy: 0.977], Valid [Loss: 1.913, Accuracy: 0.728]]
# EPOCH: 50, Train [Loss: 0.067, Accuracy: 0.978], Valid [Loss: 1.849, Accuracy: 0.733]]
# EPOCH: 51, Train [Loss: 0.084, Accuracy: 0.973], Valid [Loss: 1.862, Accuracy: 0.740]]
# EPOCH: 52, Train [Loss: 0.073, Accuracy: 0.976], Valid [Loss: 1.968, Accuracy: 0.719]]
# EPOCH: 53, Train [Loss: 0.078, Accuracy: 0.975], Valid [Loss: 1.834, Accuracy: 0.738]]
# EPOCH: 54, Train [Loss: 0.052, Accuracy: 0.983], Valid [Loss: 2.102, Accuracy: 0.740]]
# EPOCH: 55, Train [Loss: 0.074, Accuracy: 0.976], Valid [Loss: 1.820, Accuracy: 0.751]]
# EPOCH: 56, Train [Loss: 0.057, Accuracy: 0.981], Valid [Loss: 2.034, Accuracy: 0.729]]
# EPOCH: 57, Train [Loss: 0.060, Accuracy: 0.979], Valid [Loss: 2.041, Accuracy: 0.739]]
# EPOCH: 58, Train [Loss: 0.070, Accuracy: 0.977], Valid [Loss: 1.983, Accuracy: 0.731]]
# EPOCH: 59, Train [Loss: 0.060, Accuracy: 0.980], Valid [Loss: 2.065, Accuracy: 0.735]]
# EPOCH: 60, Train [Loss: 0.082, Accuracy: 0.974], Valid [Loss: 1.778, Accuracy: 0.750]]
# EPOCH: 61, Train [Loss: 0.054, Accuracy: 0.982], Valid [Loss: 1.932, Accuracy: 0.751]]
# EPOCH: 62, Train [Loss: 0.061, Accuracy: 0.979], Valid [Loss: 1.961, Accuracy: 0.745]]
# EPOCH: 63, Train [Loss: 0.052, Accuracy: 0.984], Valid [Loss: 2.069, Accuracy: 0.737]]
# EPOCH: 64, Train [Loss: 0.055, Accuracy: 0.981], Valid [Loss: 2.115, Accuracy: 0.736]]
# EPOCH: 65, Train [Loss: 0.058, Accuracy: 0.982], Valid [Loss: 2.307, Accuracy: 0.709]]
# EPOCH: 66, Train [Loss: 0.059, Accuracy: 0.981], Valid [Loss: 1.825, Accuracy: 0.745]]
# EPOCH: 67, Train [Loss: 0.050, Accuracy: 0.984], Valid [Loss: 1.956, Accuracy: 0.747]]
# EPOCH: 68, Train [Loss: 0.059, Accuracy: 0.981], Valid [Loss: 1.939, Accuracy: 0.750]]
# EPOCH: 69, Train [Loss: 0.061, Accuracy: 0.981], Valid [Loss: 2.029, Accuracy: 0.746]]
# EPOCH: 70, Train [Loss: 0.061, Accuracy: 0.980], Valid [Loss: 2.107, Accuracy: 0.737]]
# EPOCH: 71, Train [Loss: 0.051, Accuracy: 0.983], Valid [Loss: 1.942, Accuracy: 0.748]]
# EPOCH: 72, Train [Loss: 0.043, Accuracy: 0.985], Valid [Loss: 1.999, Accuracy: 0.745]]
# EPOCH: 73, Train [Loss: 0.055, Accuracy: 0.982], Valid [Loss: 2.016, Accuracy: 0.744]]
# EPOCH: 74, Train [Loss: 0.070, Accuracy: 0.978], Valid [Loss: 1.992, Accuracy: 0.745]]
# EPOCH: 75, Train [Loss: 0.046, Accuracy: 0.985], Valid [Loss: 2.053, Accuracy: 0.755]]
# EPOCH: 76, Train [Loss: 0.054, Accuracy: 0.983], Valid [Loss: 2.018, Accuracy: 0.740]]
# EPOCH: 77, Train [Loss: 0.034, Accuracy: 0.988], Valid [Loss: 2.265, Accuracy: 0.742]]
# EPOCH: 78, Train [Loss: 0.066, Accuracy: 0.979], Valid [Loss: 2.061, Accuracy: 0.745]]
# EPOCH: 79, Train [Loss: 0.062, Accuracy: 0.980], Valid [Loss: 3.089, Accuracy: 0.684]]
# EPOCH: 80, Train [Loss: 0.041, Accuracy: 0.987], Valid [Loss: 2.132, Accuracy: 0.748]]
# EPOCH: 81, Train [Loss: 0.047, Accuracy: 0.986], Valid [Loss: 2.315, Accuracy: 0.737]]
# EPOCH: 82, Train [Loss: 0.053, Accuracy: 0.983], Valid [Loss: 2.156, Accuracy: 0.745]]
# EPOCH: 83, Train [Loss: 0.055, Accuracy: 0.983], Valid [Loss: 2.079, Accuracy: 0.748]]
# EPOCH: 84, Train [Loss: 0.045, Accuracy: 0.985], Valid [Loss: 2.066, Accuracy: 0.749]]
# EPOCH: 85, Train [Loss: 0.042, Accuracy: 0.987], Valid [Loss: 2.186, Accuracy: 0.746]]
# EPOCH: 86, Train [Loss: 0.049, Accuracy: 0.984], Valid [Loss: 2.375, Accuracy: 0.734]]
# EPOCH: 87, Train [Loss: 0.052, Accuracy: 0.983], Valid [Loss: 2.257, Accuracy: 0.747]]
# EPOCH: 88, Train [Loss: 0.058, Accuracy: 0.982], Valid [Loss: 2.158, Accuracy: 0.748]]
# EPOCH: 89, Train [Loss: 0.046, Accuracy: 0.985], Valid [Loss: 2.219, Accuracy: 0.747]]
# EPOCH: 90, Train [Loss: 0.035, Accuracy: 0.989], Valid [Loss: 2.343, Accuracy: 0.744]]
# EPOCH: 91, Train [Loss: 0.049, Accuracy: 0.985], Valid [Loss: 2.211, Accuracy: 0.748]]
# EPOCH: 92, Train [Loss: 0.045, Accuracy: 0.985], Valid [Loss: 2.122, Accuracy: 0.750]]
# EPOCH: 93, Train [Loss: 0.041, Accuracy: 0.987], Valid [Loss: 2.332, Accuracy: 0.747]]
# EPOCH: 94, Train [Loss: 0.054, Accuracy: 0.983], Valid [Loss: 2.273, Accuracy: 0.735]]
# EPOCH: 95, Train [Loss: 0.053, Accuracy: 0.984], Valid [Loss: 2.049, Accuracy: 0.748]]
# EPOCH: 96, Train [Loss: 0.040, Accuracy: 0.988], Valid [Loss: 2.256, Accuracy: 0.747]]
# EPOCH: 97, Train [Loss: 0.047, Accuracy: 0.985], Valid [Loss: 2.085, Accuracy: 0.756]]
# EPOCH: 98, Train [Loss: 0.039, Accuracy: 0.987], Valid [Loss: 2.426, Accuracy: 0.743]]
# EPOCH: 99, Train [Loss: 0.053, Accuracy: 0.984], Valid [Loss: 2.353, Accuracy: 0.735]]
# EPOCH: 100, Train [Loss: 0.053, Accuracy: 0.983], Valid [Loss: 2.235, Accuracy: 0.747]]

# %%
import torchvision
testset = torchvision.datasets.CIFAR10(root='./data', train=False, download=True, transform=transforms.ToTensor() )
testloader = torch.utils.data.DataLoader(testset, batch_size=4, shuffle=True, num_workers=2)

correct = 0
total = 0
# 勾配を記憶せず（学習せずに）に計算を行う
with torch.no_grad():
    for data in testloader:
        images, labels = data[0].to(device),data[1].to(device)
        outputs = model(images)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()
print('Accuracy of the network on the 10000 test images: %d %%' % (100 * correct / total))
# Out:
# Files already downloaded and verified
# Accuracy of the network on the 10000 test images: 74 %

# %%
import torchvision
testset = torchvision.datasets.CIFAR10(root='./data', train=False, download=True, transform=transforms.ToTensor() )
testloader = torch.utils.data.DataLoader(testset, batch_size=4, shuffle=True, num_workers=2)

correct = 0
total = 0
# 勾配を記憶せず（学習せずに）に計算を行う
with torch.no_grad():
    for data in testloader:
        images, labels = data[0].to(device), data[1].to(device)
        outputs = conv_net2(images)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()
print('Accuracy of the network on the 10000 test images: %d %%' % (100 * correct / total))
# Out:
# Files already downloaded and verified
# Accuracy of the network on the 10000 test images: 73 %
